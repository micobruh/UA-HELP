# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_excel("ukraine_checkpoint.xlsx", sheet_name = "Border Crossings")
df = pd.read_excel("hk_checkpoint.xlsx", sheet_name = "Border Crossings")
df
# Out:
#                             Name - English Name - Ukrainian Country  \
# 0                      Lo Wu Control Point            羅湖管制站   China
# 1      Lok Ma Chau Spur Line Control Point         落馬洲支線管制站   China
# 2                Lok Ma Chau Control Point           落馬洲管制站   China
# 3                Sha Tau Kok Control Point           沙頭角管制站   China
# 4                 Man Kam To Control Point           文錦渡管制站   China
# 5                        Shenzhen Bay Port            深圳灣口岸   China
# 6            Hong Kong–Zhuhai–Macau Bridge            港珠澳大橋   China
# 7             Heung Yuen Wai Control Point           香園圍管制站   China
# 8   Hong Kong West Kowloon Railway Station           香港西九龍站   China
# 9                         Hung Hom Station              紅磡站   China
# 10          Hong Kong China Ferry Terminal             中港碼頭   China
# 11          Hong Kong–Macau Ferry Terminal           港澳客輪碼頭   China
# 12                     Tuen Mun Ferry Pier             屯門碼頭   China
# ...

# %%
df.to_csv("hk_checkpoint.csv", index = False)
